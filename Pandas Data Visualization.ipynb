# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
a = np.random.rand(2500).reshape(500, 5)
df = pd.DataFrame(a, columns=["a", "b", "c", "d", "e"])
df.shape
# Out:
# (500, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# e    500 non-null float64
# dtypes: float64(5)
# memory usage: 19.6 KB

# %%
df.head()
# Out:
#           a         b         c         d         e
# 0  0.989232  0.114121  0.747894  0.156074  0.089654
# 1  0.616915  0.432024  0.516519  0.658650  0.581264
# 2  0.495898  0.082160  0.757197  0.271099  0.197392
# 3  0.253234  0.049631  0.764008  0.160555  0.231974
# 4  0.872960  0.286847  0.101728  0.797624  0.130414

# %%
df.tail()
# Out:
#             a         b         c         d         e
# 495  0.070182  0.283638  0.753847  0.896550  0.752612
# 496  0.544995  0.430969  0.957572  0.391750  0.463751
# 497  0.317668  0.784451  0.799138  0.120677  0.189071
# 498  0.434407  0.538025  0.013568  0.319797  0.114502
# 499  0.245655  0.212421  0.265740  0.918989  0.097744

# %%
df.describe()
# Out:
#                 a           b           c           d           e
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.485560    0.503235    0.487704    0.509445    0.481667
# std      0.281552    0.279389    0.290856    0.290436    0.298806
# min      0.001908    0.001103    0.001517    0.000500    0.000610
# 25%      0.248584    0.283623    0.235973    0.273158    0.219848
# 50%      0.467195    0.476942    0.493623    0.495232    0.463552
# 75%      0.709716    0.735542    0.738078    0.764464    0.740495
# max      0.999112    0.996009    0.999002    0.999113    0.999167

# %%
df.plot.scatter(x='a', y='b', c='red', s=50, figsize=(12,3))

# %%
df['a'].plot.hist(bins=100)

# %%
df['a'].plot.hist(bins=10, color="r")

# %%
plt.style.use('ggplot')

# %%
df['a'].plot.hist(alpha=0.5, bins=25)

# %%
df['a'].plot.hist(alpha=1, bins=25)

# %%
plt.style.use('bmh')

# %%
df['a'].hist(color='red', alpha=0.5, bins=25)

# %%
#plt.style.use('dark_background')
#df['a'].hist()

# %%
#df.style.use('fivethirtyeight')
#df['a'].hist()

# %%
df[['a', 'b']].plot.box()

# %%
df.plot.box()

# %%
df['d'].plot.kde()

# %%
df['a'].plot.kde()

# %%
df['d'].plot.density(lw=5, ls='--')

# %%
df.loc[0:30].plot.area(alpha=0.4) # Area plot of all columns for the rows up to 30

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r')
plt.xlabel("X = x")
plt.ylabel("Y = x^2")
plt.title("x vs. x^2")
plt.show()
