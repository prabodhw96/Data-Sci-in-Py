# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.

# %%
a = np.random.rand(2500).reshape(500, 5)
df = pd.DataFrame(a, columns=["a", "b", "c", "d", "e"])
df.shape
# Out:
# (500, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# e    500 non-null float64
# dtypes: float64(5)
# memory usage: 19.6 KB

# %%
df.head()
# Out:
#           a         b         c         d         e
# 0  0.879672  0.655713  0.803350  0.601543  0.989935
# 1  0.295192  0.494638  0.343157  0.465608  0.754889
# 2  0.633835  0.470533  0.191685  0.902956  0.722399
# 3  0.769430  0.829571  0.809591  0.163495  0.023253
# 4  0.932406  0.452817  0.187072  0.927468  0.623096

# %%
df.tail()
# Out:
#             a         b         c         d         e
# 495  0.073109  0.191444  0.443864  0.760657  0.208522
# 496  0.825960  0.209750  0.788396  0.037449  0.495865
# 497  0.871042  0.508070  0.808712  0.581952  0.970160
# 498  0.413111  0.361652  0.154936  0.285139  0.643486
# 499  0.861468  0.068952  0.339378  0.283740  0.169277

# %%
df.describe()
# Out:
#                 a           b           c           d           e
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.513232    0.525026    0.517951    0.511585    0.501294
# std      0.286507    0.291271    0.297121    0.293845    0.284675
# min      0.003331    0.002194    0.003661    0.002887    0.002691
# 25%      0.270476    0.288325    0.269773    0.261316    0.252244
# 50%      0.511694    0.535827    0.536132    0.507282    0.510310
# 75%      0.779383    0.792774    0.776898    0.759647    0.754496
# max      0.998119    0.997534    0.998657    0.999279    0.996306

# %%
df.plot.scatter(x='a', y='b', c='red', s=50, figsize=(12,3))

# %%
df['a'].plot.hist(bins=100)

# %%
df['a'].plot.hist(bins=10, color="r")

# %%
plt.style.use('ggplot')

# %%
df['a'].plot.hist(alpha=0.5, bins=25)

# %%
df['a'].plot.hist(alpha=1, bins=25)

# %%
plt.style.use('bmh')

# %%
df['a'].hist(color='red', alpha=0.5, bins=25)

# %%
#plt.style.use('dark_background')
#df['a'].hist()

# %%
#df.style.use('fivethirtyeight')
#df['a'].hist()

# %%
df[['a', 'b']].plot.box()

# %%
df.plot.box()

# %%
df['d'].plot.kde()

# %%
df['a'].plot.kde()

# %%
df['d'].plot.density(lw=5, ls='--')

# %%
df.loc[0:30].plot.area(alpha=0.4) # Area plot of all columns for the rows up to 30

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r')
plt.xlabel("X = x")
plt.ylabel("Y = x^2")
plt.title("x vs. x^2")
plt.show()
