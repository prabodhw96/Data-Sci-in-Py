# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
a = np.random.rand(2500).reshape(500, 5)
df = pd.DataFrame(a, columns=["a", "b", "c", "d", "e"])
df.shape
# Out:
# (500, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# e    500 non-null float64
# dtypes: float64(5)
# memory usage: 19.6 KB

# %%
df.head()
# Out:
#           a         b         c         d         e
# 0  0.062391  0.798549  0.815943  0.907882  0.241568
# 1  0.247932  0.210714  0.095077  0.055412  0.657926
# 2  0.340758  0.107730  0.269915  0.450717  0.808562
# 3  0.819499  0.293878  0.211363  0.535211  0.201683
# 4  0.428445  0.013060  0.766311  0.446601  0.472550

# %%
df.tail()
# Out:
#             a         b         c         d         e
# 495  0.534936  0.545708  0.554440  0.828536  0.960068
# 496  0.665204  0.806374  0.251325  0.315596  0.302169
# 497  0.738829  0.485469  0.214458  0.449531  0.847415
# 498  0.265254  0.335490  0.530062  0.513965  0.101962
# 499  0.275906  0.121498  0.830410  0.279810  0.324475

# %%
df.describe()
# Out:
#                 a           b           c           d           e
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.497100    0.487269    0.484776    0.488038    0.498903
# std      0.291485    0.290852    0.289949    0.278556    0.290547
# min      0.000757    0.001820    0.000811    0.000260    0.001455
# 25%      0.246287    0.234386    0.222342    0.248880    0.248108
# 50%      0.483362    0.476372    0.478675    0.490886    0.489428
# 75%      0.743322    0.734988    0.722374    0.711742    0.755741
# max      0.997744    0.999214    0.999639    0.994430    0.994333

# %%
df.plot.scatter(x='a', y='b', c='red', s=50, figsize=(12,3))

# %%
df['a'].plot.hist(bins=100)

# %%
df['a'].plot.hist(bins=10, color="r")

# %%
plt.style.use('ggplot')

# %%
df['a'].plot.hist(alpha=0.5, bins=25)

# %%
df['a'].plot.hist(alpha=1, bins=25)

# %%
plt.style.use('bmh')

# %%
df['a'].hist(color='red', alpha=0.5, bins=25)

# %%
#plt.style.use('dark_background')
#df['a'].hist()

# %%
#df.style.use('fivethirtyeight')
#df['a'].hist()

# %%
df[['a', 'b']].plot.box()

# %%
df.plot.box()

# %%
df['d'].plot.kde()

# %%
df['a'].plot.kde()

# %%
df['d'].plot.density(lw=5, ls='--')

# %%
df.loc[0:30].plot.area(alpha=0.4) # Area plot of all columns for the rows up to 30

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r')
plt.xlabel("X = x")
plt.ylabel("Y = x^2")
plt.title("x vs. x^2")
plt.show()
